# %%
pip install folium
# Out:
# Requirement already satisfied: folium in /Users/henryhong/anaconda3/lib/python3.11/site-packages (0.19.5)
# Requirement already satisfied: branca>=0.6.0 in /Users/henryhong/anaconda3/lib/python3.11/site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /Users/henryhong/anaconda3/lib/python3.11/site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /Users/henryhong/anaconda3/lib/python3.11/site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /Users/henryhong/anaconda3/lib/python3.11/site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in /Users/henryhong/anaconda3/lib/python3.11/site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/henryhong/anaconda3/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/henryhong/anaconda3/lib/python3.11/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/henryhong/anaconda3/lib/python3.11/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/henryhong/anaconda3/lib/python3.11/site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/henryhong/anaconda3/lib/python3.11/site-packages (from requests->folium) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import folium
import os
import matplotlib.pyplot as plt

# %%
# Read files

# I'm storing GIS data in a folder called GIS_Data
file_path = os.path.join(os.getcwd(), "..", "Mekar Raya GIS Data", "Merge_Desa_AKKM.shp")
df = gpd.read_file(file_path)
df
# Out:
#   Cell In[9], line 4
#     df = gpd.read_file(/Users/henryhong/Downloads/Mekar Raya GIS Data/Merge_Desa_AKKM.shp)
#                        ^
# SyntaxError: invalid syntax

# %%
fig, ax = plt.subplots(figsize=(8, 6))
df.plot(
    column="NAMA",
    categorical=True,
    legend=True,
    legend_kwds={
        "loc": "upper left", 
        "bbox_to_anchor": (1, 1)
    },
    ax=ax
)
# Out:
# <Axes: >

# %%
m = folium.Map(location=[-0.8833, 110.33], tiles ='Stadia.AlidadeSatellite', zoom_start=13)

folium.GeoJson(
    df.loc[df['NAMA'] == 'Tembawang'],
    name="Tembawang",
    tooltip=folium.GeoJsonTooltip(
        fields=["Keterangan"],
        localize=True
    )
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de7039943475dc15b3305ffc91538e7a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de7039943475dc15b3305ffc91538e7a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de7039943475dc15b3305ffc91538e7a = L.map(
#                 &quot;map_de7039943475dc15b3305ffc91538e7a&quot;,
#                 {
#                     center: [-0.8833, 110.33],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9a043a36203358f67638fa28af056b9 = L.tileLayer(
#                 &quot;https://tiles.stadiamaps.com/tiles/alidade_satellite/{z}/{x}/{y}{r}.jpg&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; CNES, Distribution Airbus DS, \u00a9 Airbus DS, \u00a9 PlanetObserver (Contains Copernicus Data) | \u0026copy; \u003ca href=\&quot;https://www.stadiamaps.com/\&quot; target=\&quot;_blank\&quot;\u003eStadia Maps\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://openmaptiles.org/\&quot; target=\&quot;_blank\&quot;\u003eOpenMapTiles\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e9a043a36203358f67638fa28af056b9.addTo(map_de7039943475dc15b3305ffc91538e7a);
#
#
#
#         function geo_json_b9040c43ff640cb3854c2cf8d13317fb_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_b9040c43ff640cb3854c2cf8d13317fb = L.geoJson(null, {
#                 onEachFeature: geo_json_b9040c43ff640cb3854c2cf8d13317fb_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_b9040c43ff640cb3854c2cf8d13317fb_add (data) {
#             geo_json_b9040c43ff640cb3854c2cf8d13317fb
#                 .addData(data);
#         }
#             geo_json_b9040c43ff640cb3854c2cf8d13317fb_add({&quot;bbox&quot;: [110.29401290184151, -0.9025018324388787, 110.35824575929604, -0.8523680528306251], &quot;features&quot;: [{&quot;bbox&quot;: [110.34318498658733, -0.8838866251604958, 110.34589905656145, -0.8803202172940326], &quot;geometry&quot;: {&quot;coordinates&quot;: [[